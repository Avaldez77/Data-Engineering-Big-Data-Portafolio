# %% [markdown]
# # Ingestion & Parsing (PySpark)

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('observability-demo').getOrCreate()
spark.read.text('data/raw/logs.txt').show(5, truncate=False)

# %%
# !python src/pipeline/ingest_logs.py

# %%
spark.table('silver_ops_event').show(10, truncate=False)
